# %% [markdown]
# Q1. To convert two lists into dictionary.

# %%
list1 = [1,2,3,4,5,7,8]
list2 = ["a","b","c","d","e"]
 
result = {v: list2[i % len(list2)]  
 
          for i, v in enumerate(list1)} 
 
  
 
print("resultant dictionary : ", str(result))
# Out:
# resultant dictionary :  {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e', 7: 'a', 8: 'b'}
